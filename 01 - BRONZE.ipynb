# %% [markdown]
# # 🥉 BRONZE LAYER

# %%
# %run "./00 - DDL"

# %%
spark.sql(
    f"""
    COPY INTO {BRONZE_GAMES_TABLE}
    FROM '{GAMES_DIRECTORY}'
    FILEFORMAT = PARQUET
    PATTERN = '*.parquet'
    FORMAT_OPTIONS ('mergeSchema' = 'true')
    COPY_OPTIONS (
        'mergeSchema' = 'true', 
        'force' = 'false');
    """
)
